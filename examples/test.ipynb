# %%
import os

os.chdir("../")

# %%
from face_sim import FaceIdentification

face_sim_class = FaceIdentification(face_detector_path="models/yolov8n-face.pt",
                                    every_nth=5,
                                    max_frames=1,
                                    model_name="Facenet512",
                                    distance_metric="euclidean_l2",
                                    enforce_detection=True,
                                    detector_backend="yolov8",
                                    threshold=None,
                                    device="gpu",
                                    distance_threshold=0.9,
                                    mongo_ip="localhost",
                                    mongo_port=27017)

# %%
face_sim_class.update_db(["examples/References/_DSC0010.jpg", "examples/References/_DSC0619.jpg"])
# Out:
# Finding representations: 100%|████████████████████████████████████████| 2/2 [01:04<00:00, 32.45s/it]
# 2025-05-10 23:17:43,922 - INFO - 3 representations added to database.

# %%
face_sim_class.get_identities()
# Out:
# ['DSC0436.jpg',
#  'DSC0494.jpg',
#  'DSC0117.jpg',
#  'DSC0117.jpg',
#  'DSC0117.jpg',
#  'DSC0691.jpg',
#  'DSC0702.jpg',
#  '_DSC0010.jpg',
#  '_DSC0010.jpg',
#  '_DSC0619.jpg']

# %%
images_details = face_sim_class.face_id(video_path="examples/Videos/video_2025-02-22_22-54-35.mp4")

images_details
# Out:
# 2025-05-10 23:31:10,202 - INFO - Extracting frames from video: examples/Videos/video_2025-02-22_22-54-35.mp4
# 2025-05-10 23:31:10,214 - INFO - Processing video: examples/Videos/video_2025-02-22_22-54-35.mp4
# 2025-05-10 23:31:15,947 - INFO - Successfully extracted 1 frames.
# 2025-05-10 23:31:15,952 - INFO - Attempting to identify face in the frame.
# 2025-05-10 23:31:22,826 - INFO - Face identified successfully.
# 2025-05-10 23:31:22,830 - INFO - Face identification completed successfully.
# 25-05-10 23:31:22 - find function duration 6.873431444168091 seconds
# {'time': {'video_processing_time': 5.748523950576782,
#   'face_matching_time': 6.875428915023804},
#  'image_path': ['_DSC0619.jpg', 'DSC0494.jpg', 'DSC0436.jpg']}
